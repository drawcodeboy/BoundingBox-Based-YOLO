# %%
# !git clone https://github.com/drawcodeboy/BoundingBox-Based-YOLO.git
# Out:
# Cloning into 'BoundingBox-Based-YOLO'...
# remote: Enumerating objects: 137, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 137 (delta 67), reused 102 (delta 35), pack-reused 0
# Receiving objects: 100% (137/137), 31.54 KiB | 15.77 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
import os

# 현재 작업 경로 확인
print(os.getcwd())

# cwd 변경
os.chdir('/content/BoundingBox-Based-YOLO')

# 현재 작업 경로 확인
print(os.getcwd())
# Out:
# /content
# /content/BoundingBox-Based-YOLO

# %%
import zipfile

# 파일 경로 입력
zip_file_name = '/content/drive/MyDrive/Pascal VOC 2012.v1-raw.yolov5pytorch.zip'

# 압축 해제할 상위 폴더 만들기
os.mkdir('/content/BoundingBox-Based-YOLO/data/Pascal VOC 2012.v1-raw.yolov5pytorch')

# 압축 해제할 경로 입력
extraction_dir = '/content/BoundingBox-Based-YOLO/data/Pascal VOC 2012.v1-raw.yolov5pytorch'

# 압축 해제
with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
    zip_ref.extractall(extraction_dir)

# %%
# !python main.py --model=2 --mode=train --data=pascal --epochs=100 --lr=0.00001 --batch_size=16 --device=cuda --file_name_loss=bb_based_yolov1_pascal_loss.npy --file_name=bb_based_yolov1_pascal_100epochs.pt --image_dir="/content/BoundingBox-Based-YOLO/data/Pascal VOC 2012.v1-raw.yolov5pytorch/train/images" --label_dir="/content/BoundingBox-Based-YOLO/data/Pascal VOC 2012.v1-raw.yolov5pytorch/train/labels"
# Out:
# You can use GPU
# Proceed? [Y/N]: y
# 7 2 20
# Load Model Complete
# Dataset Length: 13690
# Load Dataset Complete
# ...
# Epoch: [001/100]
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Training: 100.00% Loss: 0.036541
# --------------------
# Epoch: [002/100]
# Training: 100.00% Loss: 0.032267
# --------------------
# Epoch: [003/100]
# Training: 100.00% Loss: 0.034891
# --------------------
# Epoch: [004/100]
# Training: 100.00% Loss: 0.028041
# --------------------
# Epoch: [005/100]
# Training: 100.00% Loss: 0.062882
# --------------------
# Epoch: [006/100]
# Training: 100.00% Loss: 0.041470
# --------------------
# ...

# %%
# loss.npy, #model_weights.pt 파일 다운로드 할 것!
