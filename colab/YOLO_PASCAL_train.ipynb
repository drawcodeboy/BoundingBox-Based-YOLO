# %%
# !git clone https://github.com/drawcodeboy/BoundingBox-Based-YOLO.git
# Out:
# Cloning into 'BoundingBox-Based-YOLO'...
# remote: Enumerating objects: 137, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 137 (delta 67), reused 102 (delta 35), pack-reused 0
# Receiving objects: 100% (137/137), 31.54 KiB | 10.51 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
import os

# 현재 작업 경로 확인
print(os.getcwd())

# cwd 변경
os.chdir('/content/BoundingBox-Based-YOLO')

# 현재 작업 경로 확인
print(os.getcwd())
# Out:
# /content
# /content/BoundingBox-Based-YOLO

# %%
import zipfile

# 파일 경로 입력
zip_file_name = '/content/drive/MyDrive/Pascal VOC 2012.v1-raw.yolov5pytorch.zip'

# 압축 해제할 상위 폴더 만들기
os.mkdir('/content/BoundingBox-Based-YOLO/data/Pascal VOC 2012.v1-raw.yolov5pytorch')

# 압축 해제할 경로 입력
extraction_dir = '/content/BoundingBox-Based-YOLO/data/Pascal VOC 2012.v1-raw.yolov5pytorch'

# 압축 해제
with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
    zip_ref.extractall(extraction_dir)

# %%
# !python main.py --model=1 --mode=train --data=pascal --epochs=100 --lr=0.00001 --batch_size=16 --device=cuda --file_name_loss=yolov1_pascal_loss.npy --file_name=yolov1_pascal_100epochs.pt --image_dir="/content/BoundingBox-Based-YOLO/data/Pascal VOC 2012.v1-raw.yolov5pytorch/train/images" --label_dir="/content/BoundingBox-Based-YOLO/data/Pascal VOC 2012.v1-raw.yolov5pytorch/train/labels"
# Out:
# You can use GPU
# Proceed? [Y/N]: y
# Load Model Complete
# Dataset Length: 13690
# Load Dataset Complete
# ====================
# Epoch: [001/100]
# Training: 100.00% Loss: 0.049934
# --------------------
# Epoch: [002/100]
# Training: 100.00% Loss: 0.032917
# --------------------
# Epoch: [003/100]
# Training: 100.00% Loss: 0.082561
# --------------------
# Epoch: [004/100]
# Training: 100.00% Loss: 0.050739
# --------------------
# Epoch: [005/100]
# Training: 100.00% Loss: 0.053172
# --------------------
# Epoch: [006/100]
# Training: 100.00% Loss: 0.042442
# --------------------
# Epoch: [007/100]
# Training: 100.00% Loss: 0.034544
# --------------------
# Epoch: [008/100]
# Training: 100.00% Loss: 0.028436
# --------------------
# Epoch: [009/100]
# Training: 100.00% Loss: 0.057696
# --------------------
# Epoch: [010/100]
# Training: 100.00% Loss: 0.035192
# --------------------
# Epoch: [011/100]
# Training: 100.00% Loss: 0.037072
# --------------------
# Epoch: [012/100]
# Training: 100.00% Loss: 0.021371
# --------------------
# Epoch: [013/100]
# Training: 100.00% Loss: 0.028825
# --------------------
# Epoch: [014/100]
# Training: 100.00% Loss: 0.035709
# --------------------
# Epoch: [015/100]
# Training: 100.00% Loss: 0.049787
# --------------------
# Epoch: [016/100]
# Training: 100.00% Loss: 0.016026
# --------------------
# Epoch: [017/100]
# Training: 100.00% Loss: 0.020744
# --------------------
# Epoch: [018/100]
# Training: 100.00% Loss: 0.035762
# --------------------
# Epoch: [019/100]
# Training: 100.00% Loss: 0.027801
# --------------------
# Epoch: [020/100]
# Training: 100.00% Loss: 0.016048
# --------------------
# Epoch: [021/100]
# Training: 100.00% Loss: 0.021212
# --------------------
# Epoch: [022/100]
# Training: 100.00% Loss: 0.018774
# --------------------
# Epoch: [023/100]
# Training: 100.00% Loss: 0.036329
# --------------------
# Epoch: [024/100]
# Training: 100.00% Loss: 0.024778
# --------------------
# Epoch: [025/100]
# Training: 100.00% Loss: 0.031823
# --------------------
# Epoch: [026/100]
# Training: 100.00% Loss: 0.015951
# --------------------
# Epoch: [027/100]
# Training: 100.00% Loss: 0.013335
# --------------------
# Epoch: [028/100]
# Training: 100.00% Loss: 0.016582
# --------------------
# Epoch: [029/100]
# Training: 100.00% Loss: 0.014034
# --------------------
# Epoch: [030/100]
# Training: 100.00% Loss: 0.011806
# --------------------
# Epoch: [031/100]
# Training: 100.00% Loss: 0.011214
# --------------------
# Epoch: [032/100]
# Training: 100.00% Loss: 0.011877
# --------------------
# Epoch: [033/100]
# Training: 100.00% Loss: 0.010072
# --------------------
# Epoch: [034/100]
# Training: 100.00% Loss: 0.007767
# --------------------
# Epoch: [035/100]
# Training: 100.00% Loss: 0.011655
# --------------------
# Epoch: [036/100]
# Training: 100.00% Loss: 0.011178
# --------------------
# Epoch: [037/100]
# Training: 100.00% Loss: 0.010793
# --------------------
# Epoch: [038/100]
# Training: 100.00% Loss: 0.008678
# --------------------
# Epoch: [039/100]
# Training: 100.00% Loss: 0.011461
# --------------------
# Epoch: [040/100]
# Training: 100.00% Loss: 0.020994
# --------------------
# Epoch: [041/100]
# Training: 100.00% Loss: 0.007976
# --------------------
# Epoch: [042/100]
# Training: 100.00% Loss: 0.012534
# --------------------
# Epoch: [043/100]
# Training: 100.00% Loss: 0.005971
# --------------------
# Epoch: [044/100]
# Training: 100.00% Loss: 0.005531
# --------------------
# Epoch: [045/100]
# Training: 100.00% Loss: 0.008193
# --------------------
# Epoch: [046/100]
# Training: 100.00% Loss: 0.005405
# --------------------
# Epoch: [047/100]
# Training: 100.00% Loss: 0.005787
# --------------------
# Epoch: [048/100]
# Training: 100.00% Loss: 0.004616
# --------------------
# Epoch: [049/100]
# Training: 100.00% Loss: 0.004785
# --------------------
# Epoch: [050/100]
# Training: 100.00% Loss: 0.004046
# --------------------
# Epoch: [051/100]
# Training: 100.00% Loss: 0.006112
# --------------------
# Epoch: [052/100]
# Training: 100.00% Loss: 0.005848
# --------------------
# Epoch: [053/100]
# Training: 100.00% Loss: 0.007310
# --------------------
# Epoch: [054/100]
# Training: 100.00% Loss: 0.007849
# --------------------
# Epoch: [055/100]
# Training: 100.00% Loss: 0.005618
# --------------------
# Epoch: [056/100]
# Training: 100.00% Loss: 0.008687
# --------------------
# Epoch: [057/100]
# Training: 100.00% Loss: 0.005072
# --------------------
# Epoch: [058/100]
# Training: 100.00% Loss: 0.005711
# --------------------
# Epoch: [059/100]
# Training: 100.00% Loss: 0.004247
# --------------------
# Epoch: [060/100]
# Training: 100.00% Loss: 0.012142
# --------------------
# Epoch: [061/100]
# Training: 100.00% Loss: 0.008721
# --------------------
# Epoch: [062/100]
# Training: 100.00% Loss: 0.006205
# --------------------
# Epoch: [063/100]
# Training: 100.00% Loss: 0.004074
# --------------------
# Epoch: [064/100]
# Training: 100.00% Loss: 0.006398
# --------------------
# Epoch: [065/100]
# Training: 100.00% Loss: 0.005188
# --------------------
# Epoch: [066/100]
# Training: 100.00% Loss: 0.009131
# --------------------
# Epoch: [067/100]
# Training: 100.00% Loss: 0.004450
# --------------------
# Epoch: [068/100]
# Training: 100.00% Loss: 0.004101
# --------------------
# Epoch: [069/100]
# Training: 100.00% Loss: 0.004027
# --------------------
# Epoch: [070/100]
# Training: 100.00% Loss: 0.005433
# --------------------
# Epoch: [071/100]
# Training: 100.00% Loss: 0.008720
# --------------------
# Epoch: [072/100]
# Training: 100.00% Loss: 0.009108
# --------------------
# Epoch: [073/100]
# Training: 100.00% Loss: 0.003236
# --------------------
# Epoch: [074/100]
# Training: 100.00% Loss: 0.003638
# --------------------
# Epoch: [075/100]
# Training: 100.00% Loss: 0.004334
# --------------------
# Epoch: [076/100]
# Training: 100.00% Loss: 0.004011
# --------------------
# Epoch: [077/100]
# Training: 100.00% Loss: 0.005234
# --------------------
# Epoch: [078/100]
# Training: 100.00% Loss: 0.005503
# --------------------
# Epoch: [079/100]
# Training: 100.00% Loss: 0.003303
# --------------------
# Epoch: [080/100]
# Training: 100.00% Loss: 0.004429
# --------------------
# Epoch: [081/100]
# Training: 100.00% Loss: 0.006181
# --------------------
# Epoch: [082/100]
# Training: 100.00% Loss: 0.003789
# --------------------
# Epoch: [083/100]
# Training: 100.00% Loss: 0.004200
# --------------------
# Epoch: [084/100]
# Training: 100.00% Loss: 0.005121
# --------------------
# Epoch: [085/100]
# Training: 100.00% Loss: 0.002560
# --------------------
# Epoch: [086/100]
# Training: 100.00% Loss: 0.005163
# --------------------
# Epoch: [087/100]
# Training: 100.00% Loss: 0.004326
# --------------------
# Epoch: [088/100]
# Training: 100.00% Loss: 0.004932
# --------------------
# Epoch: [089/100]
# Training: 100.00% Loss: 0.006764
# --------------------
# Epoch: [090/100]
# Training: 100.00% Loss: 0.004081
# --------------------
# Epoch: [091/100]
# Training: 100.00% Loss: 0.004901
# --------------------
# Epoch: [092/100]
# Training: 100.00% Loss: 0.003257
# --------------------
# Epoch: [093/100]
# Training: 100.00% Loss: 0.003512
# --------------------
# Epoch: [094/100]
# Training: 100.00% Loss: 0.004352
# --------------------
# Epoch: [095/100]
# Training: 100.00% Loss: 0.007805
# --------------------
# Epoch: [096/100]
# Training: 100.00% Loss: 0.002628
# --------------------
# Epoch: [097/100]
# Training: 100.00% Loss: 0.005762
# --------------------
# Epoch: [098/100]
# Training: 100.00% Loss: 0.002911
# --------------------
# Epoch: [099/100]
# Training: 100.00% Loss: 0.006229
# --------------------
# Epoch: [100/100]
# Training: 100.00% Loss: 0.003079
# --------------------
# Saving Loss Success!
# Saving Model Success!

# %%
# loss.npy, #model_weights.pt 파일 다운로드 할 것!
